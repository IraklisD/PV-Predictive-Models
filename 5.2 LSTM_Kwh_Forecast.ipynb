# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Input, Layer
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import tensorflow.keras.backend as K
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Attention, GlobalAveragePooling1D
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
# Out:
# C:\Users\hercd\AppData\Local\Temp\ipykernel_22272\4106759493.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv("/Users/iraklisdimitriadis/Documents/Μαθήματα-Σημειώσεις Data Science/Dissertation/Processed Data/cleaned_data_csv.csv", index_col= "datetime", parse_dates= True)
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\hercd\AppData\Local\Temp\ipykernel_22272\1209351260.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data = pd.read_csv("D:\Σπουδές\Μαθήματα-Σημειώσεις Data Science\Dissertation\Data\cleaned_data_csv.csv", index_col= "datetime", parse_dates= True)
#                      Kwh            name  temp  feelslike  dew  humidity  \
# datetime
# 2022-01-01 00:00:00  0.0  Kozani, Greece   6.0        4.4  2.0     75.51
# 2022-01-01 01:00:00  0.0  Kozani, Greece   6.0        5.0  2.0     75.51
# 2022-01-01 02:00:00  0.0  Kozani, Greece   4.9        3.2  2.0     81.61
# 2022-01-01 03:00:00  0.0  Kozani, Greece   4.0        4.0  1.0     80.80
# 2022-01-01 04:00:00  0.0  Kozani, Greece   3.0        1.6  2.0     93.14
#
#                      precip  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2022-01-01 00:00:00     0.0   0.0        0.0      19.8        7.6    240.0
# 2022-01-01 01:00:00     0.0   0.0        0.0      19.8        5.4    298.1
# 2022-01-01 02:00:00     0.0   NaN        0.0      20.5        7.6    301.0
# 2022-01-01 03:00:00     0.0   NaN        0.0      20.5        3.6    294.8
# 2022-01-01 04:00:00     0.0   NaN        0.0      19.8        5.4    292.3
#
#                      sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2022-01-01 00:00:00            1023.0         0.0         NaN             0.0
# 2022-01-01 01:00:00            1023.0         0.0         NaN             0.0
# 2022-01-01 02:00:00            1022.4        40.9         NaN             0.0
# 2022-01-01 03:00:00            1022.0        38.0         NaN             0.0
# 2022-01-01 04:00:00            1021.0        41.7         NaN             0.0
#
#                      solarenergy  uvindex        conditions  \
# datetime
# 2022-01-01 00:00:00          0.0      0.0             Clear
# 2022-01-01 01:00:00          0.0      0.0             Clear
# 2022-01-01 02:00:00          0.0      0.0  Partially cloudy
# 2022-01-01 03:00:00          0.0      0.0  Partially cloudy
# 2022-01-01 04:00:00          0.0      0.0  Partially cloudy
#
#                                     icon
# datetime
# 2022-01-01 00:00:00          clear-night
# 2022-01-01 01:00:00          clear-night
# 2022-01-01 02:00:00  partly-cloudy-night
# 2022-01-01 03:00:00  partly-cloudy-night
# 2022-01-01 04:00:00  partly-cloudy-night

# %%
kwh = data["Kwh"]
kwh
# Out:
# datetime
# 2022-01-01 00:00:00    0.0000
# 2022-01-01 01:00:00    0.0000
# 2022-01-01 02:00:00    0.0000
# 2022-01-01 03:00:00    0.0000
# 2022-01-01 04:00:00    0.0000
#                         ...
# 2024-07-04 19:00:00    0.0592
# 2024-07-04 20:00:00    0.0085
# 2024-07-04 21:00:00    0.0000
# 2024-07-04 22:00:00    0.0000
# 2024-07-04 23:00:00    0.0000
# Name: Kwh, Length: 21983, dtype: float64

# %% [markdown]
# # LSTM Preprocess

# %%
def df_to_x_y(df, size = 24):
    df_as_numpy = df.to_numpy()
    x = []
    y = []
    for i in range(len(df_as_numpy) - size):
        row = [[a] for a in df_as_numpy[i : i + size]]
        x.append(row)
        label = df_as_numpy[i + size]
        y.append(label)
    
    return np.array(x), np.array(y)

# %%
x, y = df_to_x_y(kwh, size= 24)

x.shape, y.shape
# Out:
# ((21959, 24, 1), (21959,))

# %%
x_train = x[: int(0.8*len(x))]
y_train = y[: int(0.8*len(y))]

x_val = x[int(0.8*len(x)): int(0.9*len(x))]
y_val = y[int(0.8*len(y)): int(0.9*len(y))]

x_test = x[int(0.9*len(x)) :]
y_test = y[int(0.9*len(y)):]

x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((17567, 24, 1), (17567,), (2196, 24, 1), (2196,), (2196, 24, 1), (2196,))

# %%
checkpoint_callback = ModelCheckpoint(
    filepath='D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras',
    monitor='val_loss',
    save_best_only=True, 
    mode='min',     
    save_weights_only=False,
    verbose=1 
)

# %%
input_shape = (24, 1)

inputs = Input(shape=input_shape)

lstm_out = LSTM(64, return_sequences=True)(inputs)
norm_out = BatchNormalization()(lstm_out)

query = norm_out
value = norm_out

attention_out = Attention()([query, value])
dropout_out = Dropout(0.2)(attention_out)
flattened = Dense(16, activation="relu")(dropout_out)
flattened = BatchNormalization()(flattened)
flattened = GlobalAveragePooling1D()(flattened)
outputs = Dense(1, activation="relu")(flattened)

model_1 = Model(inputs=inputs, outputs=outputs)

model_1.compile(
    loss=MeanSquaredError(),
    optimizer=Adam(learning_rate=1e-3),
    metrics=[RootMeanSquaredError()]
)

model_1.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 24, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 24, 64)    │     16,896 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 24, 64)    │        256 │ lstm[0][0]        │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention           │ (None, 24, 64)    │          0 │ batch_normalizat… │
# │ (Attention)         │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 24, 64)    │          0 │ attention[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 24, 16)    │      1,040 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 16)    │         64 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         17 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 18,273 (71.38 KB)
#  Trainable params: 18,113 (70.75 KB)
#  Non-trainable params: 160 (640.00 B)

# %%
model_1.fit(x_train, y_train, 
            validation_data = (x_val, y_val), 
            epochs = 40,
            batch_size= 32,
            callbacks=[checkpoint_callback]
            )
# Out:
# Epoch 1/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0242 - root_mean_squared_error: 0.1517
# Epoch 1: val_loss improved from inf to 0.03848, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0242 - root_mean_squared_error: 0.1516 - val_loss: 0.0385 - val_root_mean_squared_error: 0.1962
# Epoch 2/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985
# Epoch 2: val_loss improved from 0.03848 to 0.00755, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0869
# Epoch 3/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077 - root_mean_squared_error: 0.0875
# Epoch 3: val_loss did not improve from 0.00755
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0077 - root_mean_squared_error: 0.0875 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 4/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - root_mean_squared_error: 0.0833
# Epoch 4: val_loss did not improve from 0.00755
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0069 - root_mean_squared_error: 0.0833 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0926
# Epoch 5/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059 - root_mean_squared_error: 0.0766
# Epoch 5: val_loss improved from 0.00755 to 0.00484, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0059 - root_mean_squared_error: 0.0766 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0696
# Epoch 6/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751
# Epoch 6: val_loss improved from 0.00484 to 0.00420, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 7/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719
# Epoch 7: val_loss did not improve from 0.00420
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 8/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708
# Epoch 8: val_loss did not improve from 0.00420
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 9/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705
# Epoch 9: val_loss did not improve from 0.00420
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0732
# Epoch 10/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695
# Epoch 10: val_loss did not improve from 0.00420
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 11/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684
# Epoch 11: val_loss did not improve from 0.00420
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 12/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044 - root_mean_squared_error: 0.0665
# Epoch 12: val_loss did not improve from 0.00420
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0044 - root_mean_squared_error: 0.0665 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 13/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663
# Epoch 13: val_loss improved from 0.00420 to 0.00308, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0555
# Epoch 14/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0042 - root_mean_squared_error: 0.0644
# Epoch 14: val_loss did not improve from 0.00308
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0644 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1157
# Epoch 15/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - root_mean_squared_error: 0.0667
# Epoch 15: val_loss did not improve from 0.00308
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0045 - root_mean_squared_error: 0.0667 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0812
# Epoch 16/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651
# Epoch 16: val_loss did not improve from 0.00308
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0620
# Epoch 17/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041 - root_mean_squared_error: 0.0637
# Epoch 17: val_loss did not improve from 0.00308
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0041 - root_mean_squared_error: 0.0637 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0914
# Epoch 18/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040 - root_mean_squared_error: 0.0630
# Epoch 18: val_loss did not improve from 0.00308
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0630 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 19/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - root_mean_squared_error: 0.0617
# Epoch 19: val_loss did not improve from 0.00308
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610
# Epoch 20/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0039 - root_mean_squared_error: 0.0623
# Epoch 20: val_loss did not improve from 0.00308
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0623 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017
# Epoch 21/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - root_mean_squared_error: 0.0615
# Epoch 21: val_loss improved from 0.00308 to 0.00292, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0038 - root_mean_squared_error: 0.0615 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0541
# Epoch 22/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - root_mean_squared_error: 0.0613
# Epoch 22: val_loss did not improve from 0.00292
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0613 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0711
# Epoch 23/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - root_mean_squared_error: 0.0602
# Epoch 23: val_loss did not improve from 0.00292
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0602 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639
# Epoch 24/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0037 - root_mean_squared_error: 0.0605
# Epoch 24: val_loss did not improve from 0.00292
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0605 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0663
# Epoch 25/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - root_mean_squared_error: 0.0578
# Epoch 25: val_loss did not improve from 0.00292
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0578 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0581
# Epoch 26/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - root_mean_squared_error: 0.0604
# Epoch 26: val_loss improved from 0.00292 to 0.00257, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0604 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 27/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - root_mean_squared_error: 0.0594
# Epoch 27: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0035 - root_mean_squared_error: 0.0594 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0557
# Epoch 28/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034 - root_mean_squared_error: 0.0579
# Epoch 28: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0034 - root_mean_squared_error: 0.0579 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0588
# Epoch 29/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580
# Epoch 29: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 30/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - root_mean_squared_error: 0.0579
# Epoch 30: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0579 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0530
# Epoch 31/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - root_mean_squared_error: 0.0601
# Epoch 31: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0036 - root_mean_squared_error: 0.0601 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0779
# Epoch 32/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - root_mean_squared_error: 0.0587
# Epoch 32: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0035 - root_mean_squared_error: 0.0587 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1277
# Epoch 33/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575
# Epoch 33: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0529
# Epoch 34/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575
# Epoch 34: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 35/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - root_mean_squared_error: 0.0579
# Epoch 35: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0579 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608
# Epoch 36/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - root_mean_squared_error: 0.0560
# Epoch 36: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0031 - root_mean_squared_error: 0.0560 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0854
# Epoch 37/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - root_mean_squared_error: 0.0562
# Epoch 37: val_loss did not improve from 0.00257
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0032 - root_mean_squared_error: 0.0562 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0508
# Epoch 38/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0572
# Epoch 38: val_loss improved from 0.00257 to 0.00234, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0572 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0484
# Epoch 39/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569
# Epoch 39: val_loss did not improve from 0.00234
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0541
# Epoch 40/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575
# Epoch 40: val_loss did not improve from 0.00234
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582

# %%
test_predictions = model_1.predict(x_test).flatten()
test_results = pd.DataFrame({"Val Predictions" : test_predictions, "Real Data" : y_test})
test_results
test_results.index = kwh.iloc[-2196:].index
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
plt.figure(figsize= (16, 9))
plt.plot(test_results["Val Predictions"][9:177], label = "Forecasted")
plt.plot(test_results["Real Data"][9:177], label = "Real")
plt.legend()
plt.show()

# %%
plt.figure(figsize= (16, 9))
sns.scatterplot(x = "Real Data", y = "Val Predictions", data = test_results)
plt.xlabel("Real Values")
plt.ylabel("Forecasted Values")
plt.show()

# %%
mse = mean_squared_error(test_results["Real Data"], test_results["Val Predictions"])
print(f" Mean Squared Error = {round(mse, 5)} \n Root Mean Squared Error = {round(np.sqrt(mse), 5)}")

ss_total = np.sum((test_results["Real Data"] - test_results["Real Data"].mean()) ** 2)
residual = np.sum((test_results["Real Data"] - test_results["Val Predictions"]) ** 2)
r_squared = 1 - (residual / ss_total)

r_squared
# Out:
#  Mean Squared Error = 0.00594
#  Root Mean Squared Error = 0.07709
# 0.9042439038316742
