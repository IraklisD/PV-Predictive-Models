# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Input, Layer
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import tensorflow.keras.backend as K
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Attention, GlobalAveragePooling1D
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
# Out:
# C:\Users\hercd\AppData\Local\Temp\ipykernel_23572\4106759493.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv("D:\Σπουδές\Μαθήματα-Σημειώσεις Data Science\Dissertation\Data\cleaned_data_csv.csv", index_col= "datetime", parse_dates= True)
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\hercd\AppData\Local\Temp\ipykernel_23572\1209351260.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data = pd.read_csv("D:\Σπουδές\Μαθήματα-Σημειώσεις Data Science\Dissertation\Data\cleaned_data_csv.csv", index_col= "datetime", parse_dates= True)
#                      Kwh            name  temp  feelslike  dew  humidity  \
# datetime
# 2022-01-01 00:00:00  0.0  Kozani, Greece   6.0        4.4  2.0     75.51
# 2022-01-01 01:00:00  0.0  Kozani, Greece   6.0        5.0  2.0     75.51
# 2022-01-01 02:00:00  0.0  Kozani, Greece   4.9        3.2  2.0     81.61
# 2022-01-01 03:00:00  0.0  Kozani, Greece   4.0        4.0  1.0     80.80
# 2022-01-01 04:00:00  0.0  Kozani, Greece   3.0        1.6  2.0     93.14
#
#                      precip  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2022-01-01 00:00:00     0.0   0.0        0.0      19.8        7.6    240.0
# 2022-01-01 01:00:00     0.0   0.0        0.0      19.8        5.4    298.1
# 2022-01-01 02:00:00     0.0   NaN        0.0      20.5        7.6    301.0
# 2022-01-01 03:00:00     0.0   NaN        0.0      20.5        3.6    294.8
# 2022-01-01 04:00:00     0.0   NaN        0.0      19.8        5.4    292.3
#
#                      sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2022-01-01 00:00:00            1023.0         0.0         NaN             0.0
# 2022-01-01 01:00:00            1023.0         0.0         NaN             0.0
# 2022-01-01 02:00:00            1022.4        40.9         NaN             0.0
# 2022-01-01 03:00:00            1022.0        38.0         NaN             0.0
# 2022-01-01 04:00:00            1021.0        41.7         NaN             0.0
#
#                      solarenergy  uvindex        conditions  \
# datetime
# 2022-01-01 00:00:00          0.0      0.0             Clear
# 2022-01-01 01:00:00          0.0      0.0             Clear
# 2022-01-01 02:00:00          0.0      0.0  Partially cloudy
# 2022-01-01 03:00:00          0.0      0.0  Partially cloudy
# 2022-01-01 04:00:00          0.0      0.0  Partially cloudy
#
#                                     icon
# datetime
# 2022-01-01 00:00:00          clear-night
# 2022-01-01 01:00:00          clear-night
# 2022-01-01 02:00:00  partly-cloudy-night
# 2022-01-01 03:00:00  partly-cloudy-night
# 2022-01-01 04:00:00  partly-cloudy-night

# %%
temp = data['temp']
temp
# Out:
# datetime
# 2022-01-01 00:00:00     6.0
# 2022-01-01 01:00:00     6.0
# 2022-01-01 02:00:00     4.9
# 2022-01-01 03:00:00     4.0
# 2022-01-01 04:00:00     3.0
#                        ...
# 2024-07-04 19:00:00    24.0
# 2024-07-04 20:00:00    23.0
# 2024-07-04 21:00:00    21.0
# 2024-07-04 22:00:00    20.0
# 2024-07-04 23:00:00    18.0
# Name: temp, Length: 21983, dtype: float64

# %%
def df_to_x_y(df, size = 24):
    df_as_numpy = df.to_numpy()
    x = []
    y = []
    for i in range(len(df_as_numpy) - size):
        row = [[a] for a in df_as_numpy[i : i + size]]
        x.append(row)
        label = df_as_numpy[i + size]
        y.append(label)
    
    return np.array(x), np.array(y)

# %%
x, y = df_to_x_y(temp, size= 24)

x.shape, y.shape
# Out:
# ((21959, 24, 1), (21959,))

# %%
x_train = x[: int(0.8*len(x))]
y_train = y[: int(0.8*len(y))]

x_val = x[int(0.8*len(x)): int(0.9*len(x))]
y_val = y[int(0.8*len(y)): int(0.9*len(y))]

x_test = x[int(0.9*len(x)) :]
y_test = y[int(0.9*len(y)):]

x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((17567, 24, 1), (17567,), (2196, 24, 1), (2196,), (2196, 24, 1), (2196,))

# %%
checkpoint_callback = ModelCheckpoint(
    filepath='D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras',
    monitor='val_loss',
    save_best_only=True, 
    mode='min',     
    save_weights_only=False,
    verbose=1 
)

# %%
input_shape = (24, 1)

inputs = Input(shape=input_shape)

lstm_out = LSTM(64, return_sequences=True)(inputs)
norm_out = BatchNormalization()(lstm_out)

query = norm_out
value = norm_out

attention_out = Attention()([query, value])
dropout_out = Dropout(0.2)(attention_out)
flattened = Dense(16, activation="relu")(dropout_out)
flattened = BatchNormalization()(flattened)
flattened = GlobalAveragePooling1D()(flattened)
outputs = Dense(1, activation="relu")(flattened)

model_1 = Model(inputs=inputs, outputs=outputs)

model_1.compile(
    loss=MeanSquaredError(),
    optimizer=Adam(learning_rate=1e-3),
    metrics=[RootMeanSquaredError()]
)

model_1.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 24, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 24, 64)    │     16,896 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 24, 64)    │        256 │ lstm[0][0]        │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention           │ (None, 24, 64)    │          0 │ batch_normalizat… │
# │ (Attention)         │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 24, 64)    │          0 │ attention[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 24, 16)    │      1,040 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 16)    │         64 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         17 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 18,273 (71.38 KB)
#  Trainable params: 18,113 (70.75 KB)
#  Non-trainable params: 160 (640.00 B)

# %%
model_1.fit(x_train, y_train, 
            validation_data = (x_val, y_val), 
            epochs = 40,
            batch_size= 32,
            callbacks=[checkpoint_callback]
            )
# Out:
# Epoch 1/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 139.6291 - root_mean_squared_error: 11.6779
# Epoch 1: val_loss improved from inf to 30.79388, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 139.5258 - root_mean_squared_error: 11.6732 - val_loss: 30.7939 - val_root_mean_squared_error: 5.5492
# Epoch 2/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.1168 - root_mean_squared_error: 4.3630
# Epoch 2: val_loss did not improve from 30.79388
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 19.0946 - root_mean_squared_error: 4.3604 - val_loss: 46.6598 - val_root_mean_squared_error: 6.8308
# Epoch 3/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 11.9006 - root_mean_squared_error: 3.4444
# Epoch 3: val_loss improved from 30.79388 to 12.84327, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 11.8916 - root_mean_squared_error: 3.4430 - val_loss: 12.8433 - val_root_mean_squared_error: 3.5838
# Epoch 4/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6245 - root_mean_squared_error: 2.5725
# Epoch 4: val_loss improved from 12.84327 to 3.74651, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 6.6213 - root_mean_squared_error: 2.5719 - val_loss: 3.7465 - val_root_mean_squared_error: 1.9356
# Epoch 5/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9936 - root_mean_squared_error: 2.2338
# Epoch 5: val_loss improved from 3.74651 to 2.87064, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 4.9936 - root_mean_squared_error: 2.2338 - val_loss: 2.8706 - val_root_mean_squared_error: 1.6943
# Epoch 6/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7714 - root_mean_squared_error: 2.1835
# Epoch 6: val_loss improved from 2.87064 to 2.42976, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 4.7709 - root_mean_squared_error: 2.1834 - val_loss: 2.4298 - val_root_mean_squared_error: 1.5588
# Epoch 7/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3654 - root_mean_squared_error: 2.0889
# Epoch 7: val_loss did not improve from 2.42976
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 4.3655 - root_mean_squared_error: 2.0889 - val_loss: 2.5813 - val_root_mean_squared_error: 1.6067
# Epoch 8/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4318 - root_mean_squared_error: 2.1041
# Epoch 8: val_loss did not improve from 2.42976
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 4.4313 - root_mean_squared_error: 2.1040 - val_loss: 3.3906 - val_root_mean_squared_error: 1.8414
# Epoch 9/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5876 - root_mean_squared_error: 2.1413
# Epoch 9: val_loss did not improve from 2.42976
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 4.5860 - root_mean_squared_error: 2.1410 - val_loss: 4.7449 - val_root_mean_squared_error: 2.1783
# Epoch 10/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9485 - root_mean_squared_error: 1.9864
# Epoch 10: val_loss did not improve from 2.42976
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.9479 - root_mean_squared_error: 1.9863 - val_loss: 2.9023 - val_root_mean_squared_error: 1.7036
# Epoch 11/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0318 - root_mean_squared_error: 2.0073
# Epoch 11: val_loss did not improve from 2.42976
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 4.0317 - root_mean_squared_error: 2.0072 - val_loss: 2.7978 - val_root_mean_squared_error: 1.6727
# Epoch 12/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1195 - root_mean_squared_error: 2.0286
# Epoch 12: val_loss improved from 2.42976 to 2.20780, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 4.1193 - root_mean_squared_error: 2.0285 - val_loss: 2.2078 - val_root_mean_squared_error: 1.4859
# Epoch 13/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5402 - root_mean_squared_error: 1.8810
# Epoch 13: val_loss did not improve from 2.20780
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 3.5407 - root_mean_squared_error: 1.8812 - val_loss: 3.6681 - val_root_mean_squared_error: 1.9152
# Epoch 14/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8900 - root_mean_squared_error: 1.9705
# Epoch 14: val_loss did not improve from 2.20780
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 3.8897 - root_mean_squared_error: 1.9704 - val_loss: 5.1495 - val_root_mean_squared_error: 2.2693
# Epoch 15/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8729 - root_mean_squared_error: 1.9671
# Epoch 15: val_loss did not improve from 2.20780
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 3.8724 - root_mean_squared_error: 1.9670 - val_loss: 4.7069 - val_root_mean_squared_error: 2.1695
# Epoch 16/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4253 - root_mean_squared_error: 1.8495
# Epoch 16: val_loss improved from 2.20780 to 2.10614, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 3.4265 - root_mean_squared_error: 1.8499 - val_loss: 2.1061 - val_root_mean_squared_error: 1.4513
# Epoch 17/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2039 - root_mean_squared_error: 1.7894
# Epoch 17: val_loss did not improve from 2.10614
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 3.2045 - root_mean_squared_error: 1.7895 - val_loss: 2.8871 - val_root_mean_squared_error: 1.6992
# Epoch 18/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5265 - root_mean_squared_error: 1.8772
# Epoch 18: val_loss did not improve from 2.10614
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 3.5263 - root_mean_squared_error: 1.8772 - val_loss: 2.2743 - val_root_mean_squared_error: 1.5081
# Epoch 19/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5737 - root_mean_squared_error: 1.8862
# Epoch 19: val_loss did not improve from 2.10614
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.5730 - root_mean_squared_error: 1.8861 - val_loss: 2.2783 - val_root_mean_squared_error: 1.5094
# Epoch 20/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2214 - root_mean_squared_error: 1.7943
# Epoch 20: val_loss improved from 2.10614 to 2.07894, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.2220 - root_mean_squared_error: 1.7945 - val_loss: 2.0789 - val_root_mean_squared_error: 1.4419
# Epoch 21/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0118 - root_mean_squared_error: 1.7351
# Epoch 21: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.0119 - root_mean_squared_error: 1.7351 - val_loss: 2.6398 - val_root_mean_squared_error: 1.6247
# Epoch 22/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0374 - root_mean_squared_error: 1.7424
# Epoch 22: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.0379 - root_mean_squared_error: 1.7425 - val_loss: 2.1876 - val_root_mean_squared_error: 1.4791
# Epoch 23/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0181 - root_mean_squared_error: 1.7371
# Epoch 23: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.0186 - root_mean_squared_error: 1.7372 - val_loss: 2.4949 - val_root_mean_squared_error: 1.5795
# Epoch 24/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0424 - root_mean_squared_error: 1.7440
# Epoch 24: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.0424 - root_mean_squared_error: 1.7440 - val_loss: 2.2692 - val_root_mean_squared_error: 1.5064
# Epoch 25/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0832 - root_mean_squared_error: 1.7556
# Epoch 25: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.0832 - root_mean_squared_error: 1.7557 - val_loss: 3.1588 - val_root_mean_squared_error: 1.7773
# Epoch 26/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1185 - root_mean_squared_error: 1.7650
# Epoch 26: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.1182 - root_mean_squared_error: 1.7650 - val_loss: 2.6031 - val_root_mean_squared_error: 1.6134
# Epoch 27/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9627 - root_mean_squared_error: 1.7207
# Epoch 27: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 2.9638 - root_mean_squared_error: 1.7210 - val_loss: 2.1810 - val_root_mean_squared_error: 1.4768
# Epoch 28/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9201 - root_mean_squared_error: 1.7086
# Epoch 28: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 2.9204 - root_mean_squared_error: 1.7087 - val_loss: 2.3800 - val_root_mean_squared_error: 1.5427
# Epoch 29/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9803 - root_mean_squared_error: 1.7256
# Epoch 29: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 2.9805 - root_mean_squared_error: 1.7256 - val_loss: 2.5880 - val_root_mean_squared_error: 1.6087
# Epoch 30/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0311 - root_mean_squared_error: 1.7408
# Epoch 30: val_loss did not improve from 2.07894
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 3.0308 - root_mean_squared_error: 1.7407 - val_loss: 2.1207 - val_root_mean_squared_error: 1.4562
# Epoch 31/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8666 - root_mean_squared_error: 1.6922
# Epoch 31: val_loss improved from 2.07894 to 2.02479, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 2.8665 - root_mean_squared_error: 1.6922 - val_loss: 2.0248 - val_root_mean_squared_error: 1.4230
# Epoch 32/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0665 - root_mean_squared_error: 1.7506
# Epoch 32: val_loss did not improve from 2.02479
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 3.0662 - root_mean_squared_error: 1.7505 - val_loss: 2.5936 - val_root_mean_squared_error: 1.6105
# Epoch 33/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7478 - root_mean_squared_error: 1.6572
# Epoch 33: val_loss did not improve from 2.02479
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 2.7486 - root_mean_squared_error: 1.6574 - val_loss: 2.1194 - val_root_mean_squared_error: 1.4558
# Epoch 34/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9276 - root_mean_squared_error: 1.7099
# Epoch 34: val_loss did not improve from 2.02479
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 2.9278 - root_mean_squared_error: 1.7099 - val_loss: 2.2404 - val_root_mean_squared_error: 1.4968
# Epoch 35/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7558 - root_mean_squared_error: 1.6593
# Epoch 35: val_loss did not improve from 2.02479
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 2.7561 - root_mean_squared_error: 1.6593 - val_loss: 2.8799 - val_root_mean_squared_error: 1.6970
# Epoch 36/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0240 - root_mean_squared_error: 1.7382
# Epoch 36: val_loss did not improve from 2.02479
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.0227 - root_mean_squared_error: 1.7378 - val_loss: 2.1311 - val_root_mean_squared_error: 1.4598
# Epoch 37/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8045 - root_mean_squared_error: 1.6742
# Epoch 37: val_loss did not improve from 2.02479
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 2.8047 - root_mean_squared_error: 1.6743 - val_loss: 2.0745 - val_root_mean_squared_error: 1.4403
# Epoch 38/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7653 - root_mean_squared_error: 1.6626
# Epoch 38: val_loss did not improve from 2.02479
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 2.7655 - root_mean_squared_error: 1.6626 - val_loss: 2.8768 - val_root_mean_squared_error: 1.6961
# Epoch 39/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9608 - root_mean_squared_error: 1.7195
# Epoch 39: val_loss did not improve from 2.02479
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 2.9604 - root_mean_squared_error: 1.7194 - val_loss: 2.1947 - val_root_mean_squared_error: 1.4814
# Epoch 40/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8236 - root_mean_squared_error: 1.6796
# Epoch 40: val_loss did not improve from 2.02479
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 2.8230 - root_mean_squared_error: 1.6794 - val_loss: 2.0939 - val_root_mean_squared_error: 1.4470

# %%
test_predictions = model_1.predict(x_test).flatten()
test_results = pd.DataFrame({"Val Predictions" : test_predictions, "Real Data" : y_test})
test_results
test_results.index = temp.iloc[-2196:].index
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
plt.figure(figsize= (16, 9))
plt.plot(test_results["Val Predictions"][9:177], label = "Forecasted")
plt.plot(test_results["Real Data"][9:177], label = "Real")
plt.legend()
plt.show()

# %%
plt.figure(figsize= (16, 9))
sns.scatterplot(x = "Real Data", y = "Val Predictions", data = test_results)
plt.xlabel("Real Values")
plt.ylabel("Forecasted Values")
plt.show()

# %%
mse = mean_squared_error(test_results["Real Data"], test_results["Val Predictions"])
print(f" Mean Squared Error = {round(mse, 5)} \n Root Mean Squared Error = {round(np.sqrt(mse), 5)}")

ss_total = np.sum((test_results["Real Data"] - test_results["Real Data"].mean()) ** 2)
residual = np.sum((test_results["Real Data"] - test_results["Val Predictions"]) ** 2)
r_squared = 1 - (residual / ss_total)

r_squared
# Out:
#  Mean Squared Error = 1.85549
#  Root Mean Squared Error = 1.36216
# 0.9635064643948424
