# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Input, Layer
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Attention, GlobalAveragePooling1D
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
# Out:
# C:\Users\hercd\AppData\Local\Temp\ipykernel_14752\530672571.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv("D:\Σπουδές\Μαθήματα-Σημειώσεις Data Science\Dissertation\Data\cleaned_data_csv.csv", index_col= "datetime", parse_dates= True)
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\hercd\AppData\Local\Temp\ipykernel_14752\1209351260.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data = pd.read_csv("D:\Σπουδές\Μαθήματα-Σημειώσεις Data Science\Dissertation\Data\cleaned_data_csv.csv", index_col= "datetime", parse_dates= True)
#                      Kwh            name  temp  feelslike  dew  humidity  \
# datetime
# 2022-01-01 00:00:00  0.0  Kozani, Greece   6.0        4.4  2.0     75.51
# 2022-01-01 01:00:00  0.0  Kozani, Greece   6.0        5.0  2.0     75.51
# 2022-01-01 02:00:00  0.0  Kozani, Greece   4.9        3.2  2.0     81.61
# 2022-01-01 03:00:00  0.0  Kozani, Greece   4.0        4.0  1.0     80.80
# 2022-01-01 04:00:00  0.0  Kozani, Greece   3.0        1.6  2.0     93.14
#
#                      precip  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2022-01-01 00:00:00     0.0   0.0        0.0      19.8        7.6    240.0
# 2022-01-01 01:00:00     0.0   0.0        0.0      19.8        5.4    298.1
# 2022-01-01 02:00:00     0.0   NaN        0.0      20.5        7.6    301.0
# 2022-01-01 03:00:00     0.0   NaN        0.0      20.5        3.6    294.8
# 2022-01-01 04:00:00     0.0   NaN        0.0      19.8        5.4    292.3
#
#                      sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2022-01-01 00:00:00            1023.0         0.0         NaN             0.0
# 2022-01-01 01:00:00            1023.0         0.0         NaN             0.0
# 2022-01-01 02:00:00            1022.4        40.9         NaN             0.0
# 2022-01-01 03:00:00            1022.0        38.0         NaN             0.0
# 2022-01-01 04:00:00            1021.0        41.7         NaN             0.0
#
#                      solarenergy  uvindex        conditions  \
# datetime
# 2022-01-01 00:00:00          0.0      0.0             Clear
# 2022-01-01 01:00:00          0.0      0.0             Clear
# 2022-01-01 02:00:00          0.0      0.0  Partially cloudy
# 2022-01-01 03:00:00          0.0      0.0  Partially cloudy
# 2022-01-01 04:00:00          0.0      0.0  Partially cloudy
#
#                                     icon
# datetime
# 2022-01-01 00:00:00          clear-night
# 2022-01-01 01:00:00          clear-night
# 2022-01-01 02:00:00  partly-cloudy-night
# 2022-01-01 03:00:00  partly-cloudy-night
# 2022-01-01 04:00:00  partly-cloudy-night

# %%
wind_dir = data['winddir']
wind_dir
# Out:
# datetime
# 2022-01-01 00:00:00    240.0
# 2022-01-01 01:00:00    298.1
# 2022-01-01 02:00:00    301.0
# 2022-01-01 03:00:00    294.8
# 2022-01-01 04:00:00    292.3
#                        ...
# 2024-07-04 19:00:00    180.0
# 2024-07-04 20:00:00    172.8
# 2024-07-04 21:00:00      0.0
# 2024-07-04 22:00:00      0.0
# 2024-07-04 23:00:00      0.0
# Name: winddir, Length: 21983, dtype: float64

# %%
def df_to_x_y(df, size = 24):
    df_as_numpy = df.to_numpy()
    x = []
    y = []
    for i in range(len(df_as_numpy) - size):
        row = [[a] for a in df_as_numpy[i : i + size]]
        x.append(row)
        label = df_as_numpy[i + size]
        y.append(label)
    
    return np.array(x), np.array(y)

# %%
x, y = df_to_x_y(wind_dir, size= 24)

x.shape, y.shape
# Out:
# ((21959, 24, 1), (21959,))

# %%
x_train = x[: int(0.8*len(x))]
y_train = y[: int(0.8*len(y))]

x_val = x[int(0.8*len(x)): int(0.9*len(x))]
y_val = y[int(0.8*len(y)): int(0.9*len(y))]

x_test = x[int(0.9*len(x)) :]
y_test = y[int(0.9*len(y)):]

x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((17567, 24, 1), (17567,), (2196, 24, 1), (2196,), (2196, 24, 1), (2196,))

# %%
checkpoint_callback = ModelCheckpoint(
    filepath='D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras',
    monitor='val_loss',
    save_best_only=True, 
    mode='min',     
    save_weights_only=False,
    verbose=1 
)

# %%
input_shape = (24, 1)

inputs = Input(shape=input_shape)

lstm_out = LSTM(64, return_sequences=True)(inputs)
norm_out = BatchNormalization()(lstm_out)

query = norm_out
value = norm_out

attention_out = Attention()([query, value])
dropout_out = Dropout(0.2)(attention_out)
flattened = Dense(16, activation="relu")(dropout_out)
flattened = BatchNormalization()(flattened)
flattened = GlobalAveragePooling1D()(flattened)
outputs = Dense(1, activation="relu")(flattened)

model_1 = Model(inputs=inputs, outputs=outputs)

model_1.compile(
    loss=MeanSquaredError(),
    optimizer=Adam(learning_rate=1e-3),
    metrics=[RootMeanSquaredError()]
)

model_1.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 24, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 24, 64)    │     16,896 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 24, 64)    │        256 │ lstm[0][0]        │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention           │ (None, 24, 64)    │          0 │ batch_normalizat… │
# │ (Attention)         │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 24, 64)    │          0 │ attention[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 24, 16)    │      1,040 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 16)    │         64 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         17 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 18,273 (71.38 KB)
#  Trainable params: 18,113 (70.75 KB)
#  Non-trainable params: 160 (640.00 B)

# %%
model_1.fit(x_train, y_train, 
            validation_data = (x_val, y_val), 
            epochs = 40,
            batch_size= 32,
            callbacks=[checkpoint_callback]
            )
# Out:
# Epoch 1/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 65553.0391 - root_mean_squared_error: 256.0243
# Epoch 1: val_loss improved from inf to 56386.94531, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 65540.3750 - root_mean_squared_error: 255.9994 - val_loss: 56386.9453 - val_root_mean_squared_error: 237.4594
# Epoch 2/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 52720.1289 - root_mean_squared_error: 229.5782
# Epoch 2: val_loss improved from 56386.94531 to 35637.51953, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 52697.7539 - root_mean_squared_error: 229.5290 - val_loss: 35637.5195 - val_root_mean_squared_error: 188.7790
# Epoch 3/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 37828.8164 - root_mean_squared_error: 194.4136
# Epoch 3: val_loss improved from 35637.51953 to 24363.45312, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 37805.7461 - root_mean_squared_error: 194.3536 - val_loss: 24363.4531 - val_root_mean_squared_error: 156.0880
# Epoch 4/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26114.2520 - root_mean_squared_error: 161.5716
# Epoch 4: val_loss improved from 24363.45312 to 19290.55078, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 26098.3672 - root_mean_squared_error: 161.5218 - val_loss: 19290.5508 - val_root_mean_squared_error: 138.8904
# Epoch 5/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20075.0840 - root_mean_squared_error: 141.6734
# Epoch 5: val_loss improved from 19290.55078 to 16369.48828, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 20071.0898 - root_mean_squared_error: 141.6593 - val_loss: 16369.4883 - val_root_mean_squared_error: 127.9433
# Epoch 6/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17244.6953 - root_mean_squared_error: 131.3147
# Epoch 6: val_loss improved from 16369.48828 to 15650.85059, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 17243.8789 - root_mean_squared_error: 131.3116 - val_loss: 15650.8506 - val_root_mean_squared_error: 125.1034
# Epoch 7/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16274.7617 - root_mean_squared_error: 127.5677
# Epoch 7: val_loss improved from 15650.85059 to 15217.72461, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 16275.8213 - root_mean_squared_error: 127.5719 - val_loss: 15217.7246 - val_root_mean_squared_error: 123.3601
# Epoch 8/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15723.2236 - root_mean_squared_error: 125.3897
# Epoch 8: val_loss improved from 15217.72461 to 15148.81934, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 15723.1943 - root_mean_squared_error: 125.3896 - val_loss: 15148.8193 - val_root_mean_squared_error: 123.0805
# Epoch 9/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15081.1240 - root_mean_squared_error: 122.7803
# Epoch 9: val_loss improved from 15148.81934 to 15119.18555, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 15078.7725 - root_mean_squared_error: 122.7710 - val_loss: 15119.1855 - val_root_mean_squared_error: 122.9601
# Epoch 10/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14446.7803 - root_mean_squared_error: 120.1832
# Epoch 10: val_loss improved from 15119.18555 to 14754.80664, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 14446.6953 - root_mean_squared_error: 120.1828 - val_loss: 14754.8066 - val_root_mean_squared_error: 121.4694
# Epoch 11/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14234.8867 - root_mean_squared_error: 119.3027
# Epoch 11: val_loss improved from 14754.80664 to 14371.58008, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 14234.1748 - root_mean_squared_error: 119.2997 - val_loss: 14371.5801 - val_root_mean_squared_error: 119.8815
# Epoch 12/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14366.9922 - root_mean_squared_error: 119.8364
# Epoch 12: val_loss did not improve from 14371.58008
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 14366.5166 - root_mean_squared_error: 119.8345 - val_loss: 14764.3945 - val_root_mean_squared_error: 121.5088
# Epoch 13/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13983.4453 - root_mean_squared_error: 118.2489
# Epoch 13: val_loss improved from 14371.58008 to 13972.08594, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 13983.1846 - root_mean_squared_error: 118.2478 - val_loss: 13972.0859 - val_root_mean_squared_error: 118.2036
# Epoch 14/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13670.2305 - root_mean_squared_error: 116.9018
# Epoch 14: val_loss did not improve from 13972.08594
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 13670.4629 - root_mean_squared_error: 116.9029 - val_loss: 14279.4248 - val_root_mean_squared_error: 119.4965
# Epoch 15/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14154.6904 - root_mean_squared_error: 118.9587
# Epoch 15: val_loss did not improve from 13972.08594
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 14151.9756 - root_mean_squared_error: 118.9473 - val_loss: 14189.7588 - val_root_mean_squared_error: 119.1208
# Epoch 16/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 13859.5693 - root_mean_squared_error: 117.7239
# Epoch 16: val_loss did not improve from 13972.08594
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 13858.8926 - root_mean_squared_error: 117.7210 - val_loss: 14123.2822 - val_root_mean_squared_error: 118.8414
# Epoch 17/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13711.3018 - root_mean_squared_error: 117.0882
# Epoch 17: val_loss did not improve from 13972.08594
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 13711.2266 - root_mean_squared_error: 117.0879 - val_loss: 14506.6943 - val_root_mean_squared_error: 120.4437
# Epoch 18/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13630.9180 - root_mean_squared_error: 116.7481
# Epoch 18: val_loss did not improve from 13972.08594
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 13631.0205 - root_mean_squared_error: 116.7485 - val_loss: 14243.6094 - val_root_mean_squared_error: 119.3466
# Epoch 19/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13760.7100 - root_mean_squared_error: 117.3015
# Epoch 19: val_loss improved from 13972.08594 to 13884.72559, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 13760.3984 - root_mean_squared_error: 117.3002 - val_loss: 13884.7256 - val_root_mean_squared_error: 117.8335
# Epoch 20/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 13591.7041 - root_mean_squared_error: 116.5816
# Epoch 20: val_loss did not improve from 13884.72559
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 13591.7236 - root_mean_squared_error: 116.5816 - val_loss: 14505.1279 - val_root_mean_squared_error: 120.4372
# Epoch 21/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13678.8301 - root_mean_squared_error: 116.9541
# Epoch 21: val_loss did not improve from 13884.72559
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 13678.8369 - root_mean_squared_error: 116.9542 - val_loss: 14191.5254 - val_root_mean_squared_error: 119.1282
# Epoch 22/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 13301.9834 - root_mean_squared_error: 115.3262
# Epoch 22: val_loss did not improve from 13884.72559
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 13304.2725 - root_mean_squared_error: 115.3362 - val_loss: 14123.8223 - val_root_mean_squared_error: 118.8437
# Epoch 23/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13664.6895 - root_mean_squared_error: 116.8896
# Epoch 23: val_loss improved from 13884.72559 to 13827.62402, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 13663.1914 - root_mean_squared_error: 116.8832 - val_loss: 13827.6240 - val_root_mean_squared_error: 117.5909
# Epoch 24/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13804.2822 - root_mean_squared_error: 117.4756
# Epoch 24: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 13803.7256 - root_mean_squared_error: 117.4732 - val_loss: 14247.4521 - val_root_mean_squared_error: 119.3627
# Epoch 25/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13454.8926 - root_mean_squared_error: 115.9906
# Epoch 25: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 13455.3115 - root_mean_squared_error: 115.9924 - val_loss: 14071.1943 - val_root_mean_squared_error: 118.6221
# Epoch 26/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13656.0361 - root_mean_squared_error: 116.8453
# Epoch 26: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 13654.7588 - root_mean_squared_error: 116.8400 - val_loss: 14363.4570 - val_root_mean_squared_error: 119.8476
# Epoch 27/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13362.9795 - root_mean_squared_error: 115.5850
# Epoch 27: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 13363.7705 - root_mean_squared_error: 115.5885 - val_loss: 14168.1494 - val_root_mean_squared_error: 119.0300
# Epoch 28/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 13478.9688 - root_mean_squared_error: 116.0932
# Epoch 28: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 13478.9004 - root_mean_squared_error: 116.0929 - val_loss: 14052.9609 - val_root_mean_squared_error: 118.5452
# Epoch 29/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13471.8760 - root_mean_squared_error: 116.0658
# Epoch 29: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 13472.0771 - root_mean_squared_error: 116.0667 - val_loss: 13918.0381 - val_root_mean_squared_error: 117.9747
# Epoch 30/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13370.0029 - root_mean_squared_error: 115.6273
# Epoch 30: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 13370.8604 - root_mean_squared_error: 115.6310 - val_loss: 14413.2393 - val_root_mean_squared_error: 120.0552
# Epoch 31/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 13629.7998 - root_mean_squared_error: 116.7424
# Epoch 31: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 13629.1143 - root_mean_squared_error: 116.7394 - val_loss: 14019.5410 - val_root_mean_squared_error: 118.4041
# Epoch 32/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13381.8115 - root_mean_squared_error: 115.6754
# Epoch 32: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 13382.4609 - root_mean_squared_error: 115.6783 - val_loss: 14123.1465 - val_root_mean_squared_error: 118.8408
# Epoch 33/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13781.0449 - root_mean_squared_error: 117.3859
# Epoch 33: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 13778.3389 - root_mean_squared_error: 117.3744 - val_loss: 14241.2568 - val_root_mean_squared_error: 119.3367
# Epoch 34/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 13638.4824 - root_mean_squared_error: 116.7691
# Epoch 34: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 13637.2139 - root_mean_squared_error: 116.7637 - val_loss: 13878.1787 - val_root_mean_squared_error: 117.8057
# Epoch 35/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13084.5811 - root_mean_squared_error: 114.3777
# Epoch 35: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 13085.8271 - root_mean_squared_error: 114.3832 - val_loss: 14114.0459 - val_root_mean_squared_error: 118.8026
# Epoch 36/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13296.1123 - root_mean_squared_error: 115.3002
# Epoch 36: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 13296.5752 - root_mean_squared_error: 115.3023 - val_loss: 13976.3936 - val_root_mean_squared_error: 118.2218
# Epoch 37/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13319.7217 - root_mean_squared_error: 115.3870
# Epoch 37: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 13319.9463 - root_mean_squared_error: 115.3881 - val_loss: 14124.7783 - val_root_mean_squared_error: 118.8477
# Epoch 38/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13433.9414 - root_mean_squared_error: 115.9019
# Epoch 38: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 13433.5977 - root_mean_squared_error: 115.9004 - val_loss: 13910.2764 - val_root_mean_squared_error: 117.9418
# Epoch 39/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13390.5107 - root_mean_squared_error: 115.7082
# Epoch 39: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 13389.5557 - root_mean_squared_error: 115.7041 - val_loss: 14226.6553 - val_root_mean_squared_error: 119.2755
# Epoch 40/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13594.9473 - root_mean_squared_error: 116.5858
# Epoch 40: val_loss did not improve from 13827.62402
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 13593.5938 - root_mean_squared_error: 116.5801 - val_loss: 14325.5205 - val_root_mean_squared_error: 119.6893

# %%
test_predictions = model_1.predict(x_test).flatten()
test_results = pd.DataFrame({"Val Predictions" : test_predictions, "Real Data" : y_test})
test_results
test_results.index = wind_dir.iloc[-2196:].index
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
plt.figure(figsize= (16, 9))
plt.plot(test_results["Val Predictions"][9:177], label = "Forecasted")
plt.plot(test_results["Real Data"][9:177], label = "Real")
plt.legend()
plt.show()

# %%
plt.figure(figsize= (16, 9))
sns.scatterplot(x = "Real Data", y = "Val Predictions", data = test_results)
plt.xlabel("Real Values")
plt.ylabel("Forecasted Values")
plt.show()

# %%
mse = mean_squared_error(test_results["Real Data"], test_results["Val Predictions"])
print(f" Mean Squared Error = {round(mse, 5)} \n Root Mean Squared Error = {round(np.sqrt(mse), 5)}")

ss_total = np.sum((test_results["Real Data"] - test_results["Real Data"].mean()) ** 2)
residual = np.sum((test_results["Real Data"] - test_results["Val Predictions"]) ** 2)
r_squared = 1 - (residual / ss_total)

r_squared
# Out:
#  Mean Squared Error = 14251.89778
#  Root Mean Squared Error = 119.38131
# 0.23828305240805125
