# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Input, Layer
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Attention, GlobalAveragePooling1D
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# %%
data = pd.read_csv("/Users/iraklisdimitriadis/Documents/Μαθήματα-Σημειώσεις Data Science/Dissertation/Processed Data/cleaned_data_csv.csv", index_col= "datetime", parse_dates= True)
data.head()
# Out:
#                      Kwh            name  temp  feelslike  dew  humidity  \
# datetime
# 2022-01-01 00:00:00  0.0  Kozani, Greece   6.0        4.4  2.0     75.51
# 2022-01-01 01:00:00  0.0  Kozani, Greece   6.0        5.0  2.0     75.51
# 2022-01-01 02:00:00  0.0  Kozani, Greece   4.9        3.2  2.0     81.61
# 2022-01-01 03:00:00  0.0  Kozani, Greece   4.0        4.0  1.0     80.80
# 2022-01-01 04:00:00  0.0  Kozani, Greece   3.0        1.6  2.0     93.14
#
#                      precip  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2022-01-01 00:00:00     0.0   0.0        0.0      19.8        7.6    240.0
# 2022-01-01 01:00:00     0.0   0.0        0.0      19.8        5.4    298.1
# 2022-01-01 02:00:00     0.0   NaN        0.0      20.5        7.6    301.0
# 2022-01-01 03:00:00     0.0   NaN        0.0      20.5        3.6    294.8
# 2022-01-01 04:00:00     0.0   NaN        0.0      19.8        5.4    292.3
#
#                      sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2022-01-01 00:00:00            1023.0         0.0         NaN             0.0
# 2022-01-01 01:00:00            1023.0         0.0         NaN             0.0
# 2022-01-01 02:00:00            1022.4        40.9         NaN             0.0
# 2022-01-01 03:00:00            1022.0        38.0         NaN             0.0
# 2022-01-01 04:00:00            1021.0        41.7         NaN             0.0
#
#                      solarenergy  uvindex        conditions  \
# datetime
# 2022-01-01 00:00:00          0.0      0.0             Clear
# 2022-01-01 01:00:00          0.0      0.0             Clear
# 2022-01-01 02:00:00          0.0      0.0  Partially cloudy
# 2022-01-01 03:00:00          0.0      0.0  Partially cloudy
# 2022-01-01 04:00:00          0.0      0.0  Partially cloudy
#
#                                     icon
# datetime
# 2022-01-01 00:00:00          clear-night
# 2022-01-01 01:00:00          clear-night
# 2022-01-01 02:00:00  partly-cloudy-night
# 2022-01-01 03:00:00  partly-cloudy-night
# 2022-01-01 04:00:00  partly-cloudy-night

# %%
wind_speed = data['windspeed']
wind_speed
# Out:
# datetime
# 2022-01-01 00:00:00    7.6
# 2022-01-01 01:00:00    5.4
# 2022-01-01 02:00:00    7.6
# 2022-01-01 03:00:00    3.6
# 2022-01-01 04:00:00    5.4
#                       ...
# 2024-07-04 19:00:00    9.4
# 2024-07-04 20:00:00    3.6
# 2024-07-04 21:00:00    0.0
# 2024-07-04 22:00:00    0.0
# 2024-07-04 23:00:00    0.0
# Name: windspeed, Length: 21983, dtype: float64

# %%
def df_to_x_y(df, size = 24):
    df_as_numpy = df.to_numpy()
    x = []
    y = []
    for i in range(len(df_as_numpy) - size):
        row = [[a] for a in df_as_numpy[i : i + size]]
        x.append(row)
        label = df_as_numpy[i + size]
        y.append(label)
    
    return np.array(x), np.array(y)

# %%
x, y = df_to_x_y(wind_speed, size= 24)

x.shape, y.shape
# Out:
# ((21959, 24, 1), (21959,))

# %%
x_train = x[: int(0.8*len(x))]
y_train = y[: int(0.8*len(y))]

x_val = x[int(0.8*len(x)): int(0.9*len(x))]
y_val = y[int(0.8*len(y)): int(0.9*len(y))]

x_test = x[int(0.9*len(x)) :]
y_test = y[int(0.9*len(y)):]

x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((17567, 24, 1), (17567,), (2196, 24, 1), (2196,), (2196, 24, 1), (2196,))

# %%
checkpoint_callback = ModelCheckpoint(
    filepath='D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras',
    monitor='val_loss',
    save_best_only=True, 
    mode='min',     
    save_weights_only=False,
    verbose=1 
)

# %%
input_shape = (24, 1)

inputs = Input(shape=input_shape)

lstm_out = LSTM(64, return_sequences=True)(inputs)
norm_out = BatchNormalization()(lstm_out)

query = norm_out
value = norm_out

attention_out = Attention()([query, value])
dropout_out = Dropout(0.2)(attention_out)
flattened = Dense(16, activation="relu")(dropout_out)
flattened = BatchNormalization()(flattened)
flattened = GlobalAveragePooling1D()(flattened)
outputs = Dense(1, activation="relu")(flattened)

model_1 = Model(inputs=inputs, outputs=outputs)

model_1.compile(
    loss=MeanSquaredError(),
    optimizer=Adam(learning_rate=1e-3),
    metrics=[RootMeanSquaredError()]
)

model_1.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 24, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 24, 64)    │     16,896 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 24, 64)    │        256 │ lstm[0][0]        │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention           │ (None, 24, 64)    │          0 │ batch_normalizat… │
# │ (Attention)         │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 24, 64)    │          0 │ attention[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 24, 16)    │      1,040 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 16)    │         64 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         17 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 18,273 (71.38 KB)
#  Trainable params: 18,113 (70.75 KB)
#  Non-trainable params: 160 (640.00 B)

# %%
model_1.fit(x_train, y_train, 
            validation_data = (x_val, y_val), 
            epochs = 40,
            batch_size= 32,
            callbacks=[checkpoint_callback]
            )
# Out:
# Epoch 1/40
# 539/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.1265 - root_mean_squared_error: 7.5925
# Epoch 1: val_loss improved from inf to 25.13372, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 57.8233 - root_mean_squared_error: 7.5718 - val_loss: 25.1337 - val_root_mean_squared_error: 5.0206
# Epoch 2/40
# 540/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.5246 - root_mean_squared_error: 4.4164
# Epoch 2: val_loss improved from 25.13372 to 16.94870, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 19.5032 - root_mean_squared_error: 4.4140 - val_loss: 16.9487 - val_root_mean_squared_error: 4.1220
# Epoch 3/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.2096 - root_mean_squared_error: 4.0247
# Epoch 3: val_loss improved from 16.94870 to 16.38388, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 16.2101 - root_mean_squared_error: 4.0248 - val_loss: 16.3839 - val_root_mean_squared_error: 4.0531
# Epoch 4/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.8554 - root_mean_squared_error: 3.9818
# Epoch 4: val_loss did not improve from 16.38388
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.8554 - root_mean_squared_error: 3.9818 - val_loss: 17.6675 - val_root_mean_squared_error: 4.2095
# Epoch 5/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.8417 - root_mean_squared_error: 3.9797
# Epoch 5: val_loss did not improve from 16.38388
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.8424 - root_mean_squared_error: 3.9798 - val_loss: 16.6712 - val_root_mean_squared_error: 4.0887
# Epoch 6/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.8048 - root_mean_squared_error: 3.9754
# Epoch 6: val_loss did not improve from 16.38388
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.8052 - root_mean_squared_error: 3.9754 - val_loss: 17.3771 - val_root_mean_squared_error: 4.1741
# Epoch 7/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.7526 - root_mean_squared_error: 3.9685
# Epoch 7: val_loss did not improve from 16.38388
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.7519 - root_mean_squared_error: 3.9685 - val_loss: 18.2831 - val_root_mean_squared_error: 4.2812
# Epoch 8/40
# 543/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.6364 - root_mean_squared_error: 3.9540
# Epoch 8: val_loss did not improve from 16.38388
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.6362 - root_mean_squared_error: 3.9539 - val_loss: 17.6241 - val_root_mean_squared_error: 4.2026
# Epoch 9/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.1346 - root_mean_squared_error: 4.0165
# Epoch 9: val_loss did not improve from 16.38388
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 16.1318 - root_mean_squared_error: 4.0161 - val_loss: 17.4265 - val_root_mean_squared_error: 4.1804
# Epoch 10/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.5294 - root_mean_squared_error: 3.9404
# Epoch 10: val_loss did not improve from 16.38388
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.5302 - root_mean_squared_error: 3.9405 - val_loss: 17.3376 - val_root_mean_squared_error: 4.1695
# Epoch 11/40
# 543/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.5880 - root_mean_squared_error: 3.9479
# Epoch 11: val_loss improved from 16.38388 to 16.13117, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.5861 - root_mean_squared_error: 3.9476 - val_loss: 16.1312 - val_root_mean_squared_error: 4.0207
# Epoch 12/40
# 541/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.3858 - root_mean_squared_error: 3.9212
# Epoch 12: val_loss did not improve from 16.13117
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.3876 - root_mean_squared_error: 3.9215 - val_loss: 16.7241 - val_root_mean_squared_error: 4.0949
# Epoch 13/40
# 538/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.5255 - root_mean_squared_error: 3.9398
# Epoch 13: val_loss did not improve from 16.13117
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.5253 - root_mean_squared_error: 3.9398 - val_loss: 18.0217 - val_root_mean_squared_error: 4.2513
# Epoch 14/40
# 547/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.7185 - root_mean_squared_error: 3.9642
# Epoch 14: val_loss did not improve from 16.13117
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.7171 - root_mean_squared_error: 3.9641 - val_loss: 16.3418 - val_root_mean_squared_error: 4.0471
# Epoch 15/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.9913 - root_mean_squared_error: 3.9984
# Epoch 15: val_loss improved from 16.13117 to 16.07143, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.9905 - root_mean_squared_error: 3.9983 - val_loss: 16.0714 - val_root_mean_squared_error: 4.0140
# Epoch 16/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.2268 - root_mean_squared_error: 3.9015
# Epoch 16: val_loss did not improve from 16.07143
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.2280 - root_mean_squared_error: 3.9016 - val_loss: 16.5307 - val_root_mean_squared_error: 4.0707
# Epoch 17/40
# 538/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.2746 - root_mean_squared_error: 3.9072
# Epoch 17: val_loss did not improve from 16.07143
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.2795 - root_mean_squared_error: 3.9079 - val_loss: 16.7234 - val_root_mean_squared_error: 4.0948
# Epoch 18/40
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.1996 - root_mean_squared_error: 3.8980
# Epoch 18: val_loss improved from 16.07143 to 16.05187, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.1999 - root_mean_squared_error: 3.8980 - val_loss: 16.0519 - val_root_mean_squared_error: 4.0114
# Epoch 19/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.5921 - root_mean_squared_error: 3.9479
# Epoch 19: val_loss did not improve from 16.05187
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.5910 - root_mean_squared_error: 3.9477 - val_loss: 17.4672 - val_root_mean_squared_error: 4.1845
# Epoch 20/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.4912 - root_mean_squared_error: 3.9355
# Epoch 20: val_loss did not improve from 16.05187
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.4906 - root_mean_squared_error: 3.9354 - val_loss: 16.2079 - val_root_mean_squared_error: 4.0310
# Epoch 21/40
# 538/549 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.8055 - root_mean_squared_error: 3.9750
# Epoch 21: val_loss did not improve from 16.05187
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.7950 - root_mean_squared_error: 3.9737 - val_loss: 16.5662 - val_root_mean_squared_error: 4.0753
# Epoch 22/40
# 542/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.8701 - root_mean_squared_error: 3.8552
# Epoch 22: val_loss improved from 16.05187 to 16.01113, saving model to D:/Σπουδές/Μαθήματα-Σημειώσεις Data Science/Dissertation/Models.keras
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 14.8772 - root_mean_squared_error: 3.8561 - val_loss: 16.0111 - val_root_mean_squared_error: 4.0065
# Epoch 23/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.3659 - root_mean_squared_error: 3.9196
# Epoch 23: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.3661 - root_mean_squared_error: 3.9196 - val_loss: 16.8856 - val_root_mean_squared_error: 4.1150
# Epoch 24/40
# 546/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.0373 - root_mean_squared_error: 3.8771
# Epoch 24: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.0388 - root_mean_squared_error: 3.8773 - val_loss: 16.7416 - val_root_mean_squared_error: 4.0971
# Epoch 25/40
# 538/549 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.0790 - root_mean_squared_error: 3.8825
# Epoch 25: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.0856 - root_mean_squared_error: 3.8833 - val_loss: 16.1299 - val_root_mean_squared_error: 4.0216
# Epoch 26/40
# 542/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.9379 - root_mean_squared_error: 3.8642
# Epoch 26: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 14.9416 - root_mean_squared_error: 3.8647 - val_loss: 16.1206 - val_root_mean_squared_error: 4.0202
# Epoch 27/40
# 539/549 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.9817 - root_mean_squared_error: 3.8700
# Epoch 27: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 14.9862 - root_mean_squared_error: 3.8705 - val_loss: 16.2003 - val_root_mean_squared_error: 4.0301
# Epoch 28/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.3040 - root_mean_squared_error: 3.9113
# Epoch 28: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.3035 - root_mean_squared_error: 3.9113 - val_loss: 16.7250 - val_root_mean_squared_error: 4.0951
# Epoch 29/40
# 542/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.5765 - root_mean_squared_error: 3.9465
# Epoch 29: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.5721 - root_mean_squared_error: 3.9460 - val_loss: 17.2297 - val_root_mean_squared_error: 4.1562
# Epoch 30/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.1721 - root_mean_squared_error: 3.8950
# Epoch 30: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.1720 - root_mean_squared_error: 3.8950 - val_loss: 16.7182 - val_root_mean_squared_error: 4.0933
# Epoch 31/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.0435 - root_mean_squared_error: 3.8783
# Epoch 31: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.0464 - root_mean_squared_error: 3.8787 - val_loss: 16.2354 - val_root_mean_squared_error: 4.0343
# Epoch 32/40
# 548/549 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.1303 - root_mean_squared_error: 3.8893
# Epoch 32: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.1307 - root_mean_squared_error: 3.8894 - val_loss: 18.5753 - val_root_mean_squared_error: 4.3162
# Epoch 33/40
# 544/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.3654 - root_mean_squared_error: 3.9187
# Epoch 33: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.3622 - root_mean_squared_error: 3.9183 - val_loss: 17.4037 - val_root_mean_squared_error: 4.1777
# Epoch 34/40
# 541/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.8383 - root_mean_squared_error: 3.8514
# Epoch 34: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 14.8446 - root_mean_squared_error: 3.8522 - val_loss: 16.6998 - val_root_mean_squared_error: 4.0918
# Epoch 35/40
# 540/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.1631 - root_mean_squared_error: 3.8930
# Epoch 35: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.1624 - root_mean_squared_error: 3.8929 - val_loss: 16.3209 - val_root_mean_squared_error: 4.0447
# Epoch 36/40
# 540/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.0741 - root_mean_squared_error: 3.8819
# Epoch 36: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.0764 - root_mean_squared_error: 3.8822 - val_loss: 16.5474 - val_root_mean_squared_error: 4.0732
# Epoch 37/40
# 538/549 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.3540 - root_mean_squared_error: 3.9181
# Epoch 37: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.3535 - root_mean_squared_error: 3.9180 - val_loss: 17.4074 - val_root_mean_squared_error: 4.1775
# Epoch 38/40
# 542/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.0808 - root_mean_squared_error: 3.8831
# Epoch 38: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.0831 - root_mean_squared_error: 3.8834 - val_loss: 16.1019 - val_root_mean_squared_error: 4.0174
# Epoch 39/40
# 545/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.2670 - root_mean_squared_error: 3.9065
# Epoch 39: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 15.2667 - root_mean_squared_error: 3.9065 - val_loss: 16.0456 - val_root_mean_squared_error: 4.0106
# Epoch 40/40
# 538/549 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.9136 - root_mean_squared_error: 3.8616
# Epoch 40: val_loss did not improve from 16.01113
# 549/549 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 14.9164 - root_mean_squared_error: 3.8620 - val_loss: 16.9354 - val_root_mean_squared_error: 4.1204

# %%
test_predictions = model_1.predict(x_test).flatten()
test_results = pd.DataFrame({"Val Predictions" : test_predictions, "Real Data" : y_test})
test_results
test_results.index = wind_speed.iloc[-2196:].index
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
plt.figure(figsize= (16, 9))
plt.plot(test_results["Val Predictions"][9:177], label = "Forecasted")
plt.plot(test_results["Real Data"][9:177], label = "Real")
plt.legend()
plt.show()

# %%
plt.figure(figsize= (16, 9))
sns.scatterplot(x = "Real Data", y = "Val Predictions", data = test_results)
plt.xlabel("Real Values")
plt.ylabel("Forecasted Values")
plt.show()

# %%
mse = mean_squared_error(test_results["Real Data"], test_results["Val Predictions"])
print(f" Mean Squared Error = {round(mse, 5)} \n Root Mean Squared Error = {round(np.sqrt(mse), 5)}")

ss_total = np.sum((test_results["Real Data"] - test_results["Real Data"].mean()) ** 2)
residual = np.sum((test_results["Real Data"] - test_results["Val Predictions"]) ** 2)
r_squared = 1 - (residual / ss_total)

r_squared
# Out:
#  Mean Squared Error = 14.23889
#  Root Mean Squared Error = 3.77345
# 0.48639180310223507
