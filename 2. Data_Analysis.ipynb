# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Analysis

# %%
data = pd.read_csv("/Users/iraklisdimitriadis/Documents/Μαθήματα-Σημειώσεις Data Science/Dissertation/Processed Data/merged_df.csv")

print("\n", data.head())
print("\n", data.info())
# Out:
#                    Date  Kwh            name             datetime  temp  \
# 0  2022-01-01 00:00:00  0.0  Kozani, Greece  2022-01-01 00:00:00   6.0
# 1  2022-01-01 01:00:00  0.0  Kozani, Greece  2022-01-01 01:00:00   6.0
# 2  2022-01-01 02:00:00  0.0  Kozani, Greece  2022-01-01 02:00:00   4.9
# 3  2022-01-01 03:00:00  0.0  Kozani, Greece  2022-01-01 03:00:00   4.0
# 4  2022-01-01 04:00:00  0.0  Kozani, Greece  2022-01-01 04:00:00   3.0
#
#    feelslike  dew  humidity  precip  precipprob  ... sealevelpressure  \
# 0        4.4  2.0     75.51     0.0           0  ...           1023.0
# 1        5.0  2.0     75.51     0.0           0  ...           1023.0
# 2        3.2  2.0     81.61     0.0           0  ...           1022.4
# 3        4.0  1.0     80.80     0.0           0  ...           1022.0
# 4        1.6  2.0     93.14     0.0           0  ...           1021.0
#
#    cloudcover  visibility  solarradiation  solarenergy  uvindex  severerisk  \
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize= (16,9))
sns.set_context("notebook", font_scale=1.5)
sns.set_style("whitegrid")
sns.lineplot(x = "Date", y = "Kwh", data = data, markers= "o")
#plt.title("Time Series of Kwh")
plt.xlabel("Time")
plt.ylabel("Energy")
plt.xticks(np.arange(0, len(data), 750))
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize= (16,9))
sns.set_context("notebook", font_scale=1.5)
sns.set_style("whitegrid")
sns.lineplot(x = "Date", y = "Kwh", data = data.iloc[5015:5039], marker= "o", color = "DarkRed")
#plt.title("Time Series of Kwh in a Day")
plt.xlabel("Time")
plt.ylabel("Energy - KWH")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Temperature

# %%
plt.figure(figsize= (16,9))
sns.set_context("notebook", font_scale=1.5)
sns.set_style("whitegrid")
sns.lineplot(x = "Date", y = "temp", data = data, markers= "o")
#plt.title("Time Series of Temperature")
plt.xlabel("Time")
plt.ylabel("Temperature")
plt.xticks(np.arange(0, len(data), 750))
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize= (16,9))
sns.set_style("whitegrid")
sns.lineplot(x = "Date", y = "temp", data = data.iloc[5015:5039], marker= "o", color = "DarkRed")
#plt.title("Time Series of Temp in a Day")
plt.xlabel("Time")
plt.ylabel("Temp")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Solar Radiation

# %%
plt.figure(figsize= (16,9))
sns.set_style("darkgrid")
sns.lineplot(x = "Date", y = "solarradiation", data = data, markers= "o")
plt.title("Time Series of Solar radiation")
plt.xlabel("Time")
plt.ylabel("solar radiation")
plt.xticks(np.arange(0, len(data), 500))
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize= (16,9))
sns.set_style("darkgrid")
sns.lineplot(x = "Date", y = "solarradiation", data = data.iloc[5015:5039], markers= "O")
plt.title("Time Series of solar radiation in a Day")
plt.xlabel("Time")
plt.ylabel("solar radiation")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Solar Energy

# %%
plt.figure(figsize= (16,9))
sns.set_style("darkgrid")
sns.lineplot(x = "Date", y = "solarenergy", data = data, markers= "o")
plt.title("Time Series of Solar Energy")
plt.xlabel("Time")
plt.ylabel("solar Energy")
plt.xticks(np.arange(0, len(data), 500))
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize= (16,9))
sns.set_style("darkgrid")
sns.lineplot(x = "Date", y = "solarenergy", data = data.iloc[5015:5039], markers= "O")
plt.title("Time Series of solar Energy in a Day")
plt.xlabel("Time")
plt.ylabel("solar Energy")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Cloud Cover

# %%
plt.figure(figsize= (16,9))
sns.set_style("darkgrid")
sns.lineplot(x = "Date", y = "cloudcover", data = data, markers= "o")
plt.title("Time Series of Cloud Cover")
plt.xlabel("Time")
plt.ylabel("Cloud Cover")
plt.xticks(np.arange(0, len(data), 500))
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize= (16,9))
sns.set_style("darkgrid")
sns.lineplot(x = "Date", y = "cloudcover", data = data.iloc[5015:5039], markers= "O")
plt.title("Time Series of Cloud Cover in a Day")
plt.xlabel("Time")
plt.ylabel("Cloud Cover")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Correlation Plot Temp - KWh

# %%
plt.figure(figsize= (20,9))
sns.set_style("darkgrid")
sns.lmplot(x = "temp", y = "Kwh", data = data.iloc[5015:5735])
plt.title("Regression Plot of KWh over Temp")
plt.xlabel("Temperature")
plt.ylabel("Kwh")
plt.show()

# %% [markdown]
# # Correlation Plot SolarRad - KWh

# %%
plt.figure(figsize= (20,9))
sns.set_style("darkgrid")
sns.lmplot(x = "solarradiation", y = "Kwh", data = data.iloc[5015:5735])
plt.title("Regression Plot of KWh over solar radiatio")
plt.xlabel("solar radiatio")
plt.ylabel("Kwh")
plt.show()

# %%
plt.figure(figsize= (20,9))
sns.set_style("darkgrid")
sns.lmplot(x = "cloudcover", y = "Kwh", data = data.iloc[5015:5735])
plt.title("Regression Plot of KWh over cloudcover")
plt.xlabel("cloudcover")
plt.ylabel("Kwh")
plt.show()

# %%
plt.figure(figsize= (20,9))
sns.set_style("darkgrid")
sns.lmplot(x = "cloudcover", y = "Kwh", data = data.iloc[5015:5735])
plt.title("Regression Plot of KWh over cloudcover")
plt.xlabel("cloudcover")
plt.ylabel("Kwh")
plt.show()

# %% [markdown]
# # HeatMap

# %%
tc = data[["Kwh", "temp", "feelslike", "dew", "humidity", "windspeed", "winddir", "sealevelpressure", "cloudcover", "solarradiation", "solarenergy", "visibility", "snow", "snowdepth", "windgust", "uvindex"]].corr()

# %%
plt.figure(figsize= (16, 9))
sns.heatmap(tc, annot= True, cmap = "coolwarm")
plt.show()

# %%
print(data.isna().sum())
# Out:
# Date                    0
# Kwh                     0
# name                    0
# datetime                0
# temp                    0
# feelslike               0
# dew                     0
# humidity                0
# precip                  0
# precipprob              0
# preciptype          18916
# snow                   53
# snowdepth               0
# windgust                0
# windspeed               0
# winddir                 0
# sealevelpressure        0
# cloudcover              0
# visibility            278
# solarradiation          1
# solarenergy             1
# uvindex                 1
# severerisk            422
# conditions              0
# icon                    0
# stations                0
# dtype: int64

# %%
data["preciptype"].unique()
# Out:
# array([nan, 'rain', 'snow', 'rain,snow'], dtype=object)

# %%
data["conditions"].unique()
# Out:
# array(['Clear', 'Partially cloudy', 'Overcast', 'Rain, Overcast',
#        'Rain, Partially cloudy', 'Snow, Overcast',
#        'Snow, Partially cloudy', 'Snow', 'Snow, Rain, Overcast',
#        'Snow, Rain, Partially cloudy', 'Snow, Rain', 'Rain'], dtype=object)

# %%
pd.set_option('display.max_columns', None)

data
# Out:
#                       Date     Kwh            name             datetime  temp  \
# 0      2022-01-01 00:00:00  0.0000  Kozani, Greece  2022-01-01 00:00:00   6.0
# 1      2022-01-01 01:00:00  0.0000  Kozani, Greece  2022-01-01 01:00:00   6.0
# 2      2022-01-01 02:00:00  0.0000  Kozani, Greece  2022-01-01 02:00:00   4.9
# 3      2022-01-01 03:00:00  0.0000  Kozani, Greece  2022-01-01 03:00:00   4.0
# 4      2022-01-01 04:00:00  0.0000  Kozani, Greece  2022-01-01 04:00:00   3.0
# ...                    ...     ...             ...                  ...   ...
# 21978  2024-07-04 19:00:00  0.0592  Kozani, Greece  2024-07-04 19:00:00  24.0
# 21979  2024-07-04 20:00:00  0.0085  Kozani, Greece  2024-07-04 20:00:00  23.0
# 21980  2024-07-04 21:00:00  0.0000  Kozani, Greece  2024-07-04 21:00:00  21.0
# 21981  2024-07-04 22:00:00  0.0000  Kozani, Greece  2024-07-04 22:00:00  20.0
# 21982  2024-07-04 23:00:00  0.0000  Kozani, Greece  2024-07-04 23:00:00  18.0
#
# ...

# %%
cleaned_data = data.drop(["severerisk", "preciptype", "precipprob", "stations", "Date"],axis= 1)
cleaned_data
# Out:
#           Kwh            name             datetime  temp  feelslike   dew  \
# 0      0.0000  Kozani, Greece  2022-01-01 00:00:00   6.0        4.4   2.0
# 1      0.0000  Kozani, Greece  2022-01-01 01:00:00   6.0        5.0   2.0
# 2      0.0000  Kozani, Greece  2022-01-01 02:00:00   4.9        3.2   2.0
# 3      0.0000  Kozani, Greece  2022-01-01 03:00:00   4.0        4.0   1.0
# 4      0.0000  Kozani, Greece  2022-01-01 04:00:00   3.0        1.6   2.0
# ...       ...             ...                  ...   ...        ...   ...
# 21978  0.0592  Kozani, Greece  2024-07-04 19:00:00  24.0       24.0  10.0
# 21979  0.0085  Kozani, Greece  2024-07-04 20:00:00  23.0       23.0   9.0
# 21980  0.0000  Kozani, Greece  2024-07-04 21:00:00  21.0       21.0  10.0
# 21981  0.0000  Kozani, Greece  2024-07-04 22:00:00  20.0       20.0  11.0
# 21982  0.0000  Kozani, Greece  2024-07-04 23:00:00  18.0       18.0  11.0
#
#        humidity  precip  snow  snowdepth  windgust  windspeed  winddir  \
# ...

# %%
cleaned_data.isna().sum()
# Out:
# Kwh                   0
# name                  0
# datetime              0
# temp                  0
# feelslike             0
# dew                   0
# humidity              0
# precip                0
# snow                 53
# snowdepth             0
# windgust              0
# windspeed             0
# winddir               0
# sealevelpressure      0
# cloudcover            0
# visibility          278
# solarradiation        1
# solarenergy           1
# uvindex               1
# conditions            0
# icon                  0
# dtype: int64

# %%
cleaned_data[cleaned_data["solarenergy"].isna()]
# Out:
#           Kwh            name             datetime  temp  feelslike   dew  \
# 21900  0.6906  Kozani, Greece  2024-07-01 13:00:00  33.9       32.2  10.6
#
#        humidity  precip  snow  snowdepth  windgust  windspeed  winddir  \
# 21900     24.14     0.0   0.0        0.0      15.5        6.1    126.3
#
#        sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# 21900            1011.0         0.0         NaN             NaN          NaN
#
#        uvindex conditions       icon
# 21900      NaN      Clear  clear-day

# %%
cleaned_data.to_excel("cleaned_data.xlsx")

# %%
cleaned_data.to_csv("cleaned_data_csv.csv", index= False)
